# %%
# !pip install opensensemap-api

# %%
#get list of ifu boxes at eth
url = 'https://api.opensensemap.org/boxes?'
bbox = '8.50269672304309, 47.40598032642525,  8.512126181507432, 47.4113301084323 ' # boundary box around eth 

import requests

# %%
boxes = requests.get(url, params={'bbox':bbox}).json()

# %%
boxes = [box for box in boxes]
box_id = []
sensors_ids = []
for box in boxes:
    box_id.append(box['_id'])
    current = []
    for sensor in box['sensors']:
        try:
            current.append(sensor['_id'])
        except:
            pass
    sensors_ids.append(current)

# %%
from_date = ''
data_format = 'json'

for box, sensors in zip(box_id, sensors_ids):
    for _id in sensors:
        url = f'https://api.opensensemap.org/boxes/{box}/data/{_id}?format={data_format}'
        data = requests.get(url)
        print(data.json())
# Out:
# []
# []
# []
# []
# []
# []
# []
# ...
